# %%
#import libs
import cv2
import os
import random
import matplotlib.pylab as plt
from glob import glob
import pandas as pd
import numpy as np
import pickle
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
import keras
from keras.models import *
from keras.layers import *
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.preprocessing.image import *
from keras.callbacks import EarlyStopping
from keras import regularizers,optimizers
from keras.callbacks import LearningRateScheduler
from keras import *
from keras.applications.inception_v3 import InceptionV3
import seaborn as sns
import sklearn
from sklearn.metrics import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# TRAIN_RUN

# ../input/walk_or_run_train/train/run
train_run = glob(os.path.join('/content/drive/MyDrive/run /walk_run_train/train_run', "*.png"))

# TRAIN_WALK

train_walk = glob(os.path.join('/content/drive/MyDrive/run /walk_run_train/train_walk', "*.png"))

# ADD TRAIN_WALK AND TRAIN_RUN INTO A DATAFRAME

train = pd.DataFrame()
train['file'] = train_run + train_walk
train.head()
train
# Out:
#                                                   file
# 0    /content/drive/MyDrive/run /walk_run_train/tra...
# 1    /content/drive/MyDrive/run /walk_run_train/tra...
# 2    /content/drive/MyDrive/run /walk_run_train/tra...
# 3    /content/drive/MyDrive/run /walk_run_train/tra...
# 4    /content/drive/MyDrive/run /walk_run_train/tra...
# ..                                                 ...
# 595  /content/drive/MyDrive/run /walk_run_train/tra...
# 596  /content/drive/MyDrive/run /walk_run_train/tra...
# 597  /content/drive/MyDrive/run /walk_run_train/tra...
# 598  /content/drive/MyDrive/run /walk_run_train/tra...
# 599  /content/drive/MyDrive/run /walk_run_train/tra...
#
# [600 rows x 1 columns]

# %%
# TEST_RUN

# ../input/walk_or_run_train/train/run
test_run = glob(os.path.join('/content/drive/MyDrive/run /walk_run_test/run_test', "*.png"))

# TRAIN_WALK

test_walk = glob(os.path.join('/content/drive/MyDrive/run /walk_run_test/walk_test', "*.png"))

# ADD TRAIN_WALK AND TRAIN_RUN INTO A DATAFRAME

test = pd.DataFrame()
test['file'] = test_run + test_walk
test.head()
test
# Out:
#                                                   file
# 0    /content/drive/MyDrive/run /walk_run_test/run_...
# 1    /content/drive/MyDrive/run /walk_run_test/run_...
# 2    /content/drive/MyDrive/run /walk_run_test/run_...
# 3    /content/drive/MyDrive/run /walk_run_test/run_...
# 4    /content/drive/MyDrive/run /walk_run_test/run_...
# ..                                                 ...
# 136  /content/drive/MyDrive/run /walk_run_test/walk...
# 137  /content/drive/MyDrive/run /walk_run_test/walk...
# 138  /content/drive/MyDrive/run /walk_run_test/walk...
# 139  /content/drive/MyDrive/run /walk_run_test/walk...
# 140  /content/drive/MyDrive/run /walk_run_test/walk...
#
# [141 rows x 1 columns]

# %%
#TRAIN LABELS

train['label'] = [1 if i in train_run else 0 for i in train['file']]
train.head()
# Out:
#                                                 file  label
# 0  /content/drive/MyDrive/run /walk_run_train/tra...      1
# 1  /content/drive/MyDrive/run /walk_run_train/tra...      1
# 2  /content/drive/MyDrive/run /walk_run_train/tra...      1
# 3  /content/drive/MyDrive/run /walk_run_train/tra...      1
# 4  /content/drive/MyDrive/run /walk_run_train/tra...      1

# %%
#TEST LABELS

test['label'] = [1 if i in test_run else 0 for i in test['file']]
test.head()
# Out:
#                                                 file  label
# 0  /content/drive/MyDrive/run /walk_run_test/run_...      1
# 1  /content/drive/MyDrive/run /walk_run_test/run_...      1
# 2  /content/drive/MyDrive/run /walk_run_test/run_...      1
# 3  /content/drive/MyDrive/run /walk_run_test/run_...      1
# 4  /content/drive/MyDrive/run /walk_run_test/run_...      1

# %%
# TRAIN RUN AND WALK IMAGES
plt.figure(figsize=(16,16))
plt.imshow(cv2.imread(train_run[0]))

# %%
def dataug(files, labels, batch_size=10,randomized=True, random_seed=1):
    randomizer = np.random.RandomState(random_seed)
    img_batch = []
    label_batch = []
    while True:
        ind = np.arange(len(files))
        if randomized:
            randomizer.shuffle(ind)
        for index in ind:
            image = cv2.imread(files[index])[:,:,0:3]/255
            label = labels[index]
            img_batch.append(image)
            label_batch.append(label)
            if len(img_batch) == batch_size:
                yield np.array(img_batch), np.array(label_batch)
                img_batch = []
                label_batch = []
        
        if len(img_batch) > 0:
                yield np.array(img_batch), np.array(label_batch)
                img_batch = []
                label_batch = []

# %%
transfered=InceptionV3(include_top=False,weights='imagenet',input_tensor=None,input_shape=(None,None,3),pooling='avg',classes=1000)
model=Sequential()
model.add((InputLayer(None,None,3)))
model.add(transfered)
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
transfered.trainable=False
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['acc'])
batch_size=500
epochs=50

# %%
model.fit(dataug(train['file'],train['label'],batch_size=batch_size,randomized=True,random_seed=1),steps_per_epoch=int(np.ceil(len(train)/batch_size)), epochs=epochs,
          validation_data=dataug(test['file'],test['label'],batch_size=batch_size,randomized=True),validation_steps=int(np.ceil(len(test)/batch_size)),
          callbacks=[ModelCheckpoint(filepath='./weights.hdf5',monitor='val_loss',verbose=1,save_best_only=True)],
          verbose=1)
# Out:
# Epoch 1/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7800 - acc: 0.5317
# Epoch 1: val_loss improved from inf to 0.77363, saving model to ./weights.hdf5
# 2/2 [==============================] - 43s 42s/step - loss: 0.7800 - acc: 0.5317 - val_loss: 0.7736 - val_acc: 0.4326
# Epoch 2/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7913 - acc: 0.5133
# Epoch 2: val_loss improved from 0.77363 to 0.70693, saving model to ./weights.hdf5
# 2/2 [==============================] - 5s 4s/step - loss: 0.7913 - acc: 0.5133 - val_loss: 0.7069 - val_acc: 0.5177
# Epoch 3/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7431 - acc: 0.4983
# Epoch 3: val_loss improved from 0.70693 to 0.68338, saving model to ./weights.hdf5
# 2/2 [==============================] - 5s 4s/step - loss: 0.7431 - acc: 0.4983 - val_loss: 0.6834 - val_acc: 0.5461
# Epoch 4/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7651 - acc: 0.5167
# Epoch 4: val_loss improved from 0.68338 to 0.68222, saving model to ./weights.hdf5
# 2/2 [==============================] - 5s 4s/step - loss: 0.7651 - acc: 0.5167 - val_loss: 0.6822 - val_acc: 0.5603
# Epoch 5/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7487 - acc: 0.5083
# Epoch 5: val_loss did not improve from 0.68222
# 2/2 [==============================] - 6s 4s/step - loss: 0.7487 - acc: 0.5083 - val_loss: 0.6848 - val_acc: 0.5532
# Epoch 6/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7220 - acc: 0.5300
# Epoch 6: val_loss did not improve from 0.68222
# 2/2 [==============================] - 7s 4s/step - loss: 0.7220 - acc: 0.5300 - val_loss: 0.6989 - val_acc: 0.5319
# Epoch 7/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7373 - acc: 0.5383
# Epoch 7: val_loss did not improve from 0.68222
# 2/2 [==============================] - 6s 4s/step - loss: 0.7373 - acc: 0.5383 - val_loss: 0.7179 - val_acc: 0.4823
# Epoch 8/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7332 - acc: 0.5300
# Epoch 8: val_loss did not improve from 0.68222
# 2/2 [==============================] - 6s 4s/step - loss: 0.7332 - acc: 0.5300 - val_loss: 0.7235 - val_acc: 0.5035
# Epoch 9/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7169 - acc: 0.5483
# Epoch 9: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.7169 - acc: 0.5483 - val_loss: 0.7117 - val_acc: 0.5319
# Epoch 10/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7048 - acc: 0.5683
# Epoch 10: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.7048 - acc: 0.5683 - val_loss: 0.6965 - val_acc: 0.5532
# Epoch 11/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7216 - acc: 0.5583
# Epoch 11: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.7216 - acc: 0.5583 - val_loss: 0.6907 - val_acc: 0.5674
# Epoch 12/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6984 - acc: 0.5633
# Epoch 12: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6984 - acc: 0.5633 - val_loss: 0.6912 - val_acc: 0.5674
# Epoch 13/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7261 - acc: 0.5433
# Epoch 13: val_loss did not improve from 0.68222
# 2/2 [==============================] - 6s 4s/step - loss: 0.7261 - acc: 0.5433 - val_loss: 0.6989 - val_acc: 0.5532
# Epoch 14/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6749 - acc: 0.5867
# Epoch 14: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6749 - acc: 0.5867 - val_loss: 0.7204 - val_acc: 0.5461
# Epoch 15/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6944 - acc: 0.5600
# Epoch 15: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6944 - acc: 0.5600 - val_loss: 0.7402 - val_acc: 0.5035
# Epoch 16/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6953 - acc: 0.5833
# Epoch 16: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6953 - acc: 0.5833 - val_loss: 0.7404 - val_acc: 0.5035
# Epoch 17/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6893 - acc: 0.5933
# Epoch 17: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6893 - acc: 0.5933 - val_loss: 0.7236 - val_acc: 0.5177
# Epoch 18/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6831 - acc: 0.6067
# Epoch 18: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6831 - acc: 0.6067 - val_loss: 0.7054 - val_acc: 0.5461
# Epoch 19/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6891 - acc: 0.5650
# Epoch 19: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6891 - acc: 0.5650 - val_loss: 0.6984 - val_acc: 0.5674
# Epoch 20/50
# 2/2 [==============================] - ETA: 0s - loss: 0.7010 - acc: 0.5700
# Epoch 20: val_loss did not improve from 0.68222
# 2/2 [==============================] - 6s 4s/step - loss: 0.7010 - acc: 0.5700 - val_loss: 0.7037 - val_acc: 0.5461
# Epoch 21/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6749 - acc: 0.5833
# Epoch 21: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6749 - acc: 0.5833 - val_loss: 0.7242 - val_acc: 0.5248
# Epoch 22/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6610 - acc: 0.6083
# Epoch 22: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6610 - acc: 0.6083 - val_loss: 0.7393 - val_acc: 0.5106
# Epoch 23/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6743 - acc: 0.6100
# Epoch 23: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6743 - acc: 0.6100 - val_loss: 0.7209 - val_acc: 0.5248
# Epoch 24/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6839 - acc: 0.5883
# Epoch 24: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6839 - acc: 0.5883 - val_loss: 0.7005 - val_acc: 0.5532
# Epoch 25/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6557 - acc: 0.6133
# Epoch 25: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6557 - acc: 0.6133 - val_loss: 0.6939 - val_acc: 0.6099
# Epoch 26/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6705 - acc: 0.6050
# Epoch 26: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6705 - acc: 0.6050 - val_loss: 0.6948 - val_acc: 0.5887
# Epoch 27/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6488 - acc: 0.6250
# Epoch 27: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6488 - acc: 0.6250 - val_loss: 0.7063 - val_acc: 0.5319
# Epoch 28/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6676 - acc: 0.5967
# Epoch 28: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6676 - acc: 0.5967 - val_loss: 0.7251 - val_acc: 0.5390
# Epoch 29/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6578 - acc: 0.6217
# Epoch 29: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6578 - acc: 0.6217 - val_loss: 0.7356 - val_acc: 0.5106
# Epoch 30/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6643 - acc: 0.6117
# Epoch 30: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6643 - acc: 0.6117 - val_loss: 0.7253 - val_acc: 0.5390
# Epoch 31/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6658 - acc: 0.5917
# Epoch 31: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6658 - acc: 0.5917 - val_loss: 0.7115 - val_acc: 0.5319
# Epoch 32/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6492 - acc: 0.6117
# Epoch 32: val_loss did not improve from 0.68222
# 2/2 [==============================] - 6s 4s/step - loss: 0.6492 - acc: 0.6117 - val_loss: 0.7057 - val_acc: 0.5248
# Epoch 33/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6332 - acc: 0.6233
# Epoch 33: val_loss did not improve from 0.68222
# 2/2 [==============================] - 8s 5s/step - loss: 0.6332 - acc: 0.6233 - val_loss: 0.7036 - val_acc: 0.5461
# Epoch 34/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6537 - acc: 0.6133
# Epoch 34: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6537 - acc: 0.6133 - val_loss: 0.7032 - val_acc: 0.5532
# Epoch 35/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6505 - acc: 0.6217
# Epoch 35: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6505 - acc: 0.6217 - val_loss: 0.7073 - val_acc: 0.5319
# Epoch 36/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6540 - acc: 0.5833
# Epoch 36: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6540 - acc: 0.5833 - val_loss: 0.7092 - val_acc: 0.5461
# Epoch 37/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6475 - acc: 0.5833
# Epoch 37: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6475 - acc: 0.5833 - val_loss: 0.7069 - val_acc: 0.5461
# Epoch 38/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6236 - acc: 0.6300
# Epoch 38: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6236 - acc: 0.6300 - val_loss: 0.7069 - val_acc: 0.5532
# Epoch 39/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6344 - acc: 0.5950
# Epoch 39: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6344 - acc: 0.5950 - val_loss: 0.7080 - val_acc: 0.5532
# Epoch 40/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6204 - acc: 0.6283
# Epoch 40: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6204 - acc: 0.6283 - val_loss: 0.7046 - val_acc: 0.5461
# Epoch 41/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6424 - acc: 0.6267
# Epoch 41: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6424 - acc: 0.6267 - val_loss: 0.7023 - val_acc: 0.5390
# Epoch 42/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6343 - acc: 0.6217
# Epoch 42: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6343 - acc: 0.6217 - val_loss: 0.7022 - val_acc: 0.5390
# Epoch 43/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6230 - acc: 0.6150
# Epoch 43: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6230 - acc: 0.6150 - val_loss: 0.6980 - val_acc: 0.5461
# Epoch 44/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6291 - acc: 0.6183
# Epoch 44: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6291 - acc: 0.6183 - val_loss: 0.6939 - val_acc: 0.5532
# Epoch 45/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6395 - acc: 0.5950
# Epoch 45: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6395 - acc: 0.5950 - val_loss: 0.6930 - val_acc: 0.5532
# Epoch 46/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6066 - acc: 0.6283
# Epoch 46: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6066 - acc: 0.6283 - val_loss: 0.6967 - val_acc: 0.5319
# Epoch 47/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6240 - acc: 0.6150
# Epoch 47: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6240 - acc: 0.6150 - val_loss: 0.7038 - val_acc: 0.5461
# Epoch 48/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6198 - acc: 0.6533
# Epoch 48: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6198 - acc: 0.6533 - val_loss: 0.7073 - val_acc: 0.5532
# Epoch 49/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6269 - acc: 0.6067
# Epoch 49: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6269 - acc: 0.6067 - val_loss: 0.7094 - val_acc: 0.5532
# Epoch 50/50
# 2/2 [==============================] - ETA: 0s - loss: 0.6118 - acc: 0.6433
# Epoch 50: val_loss did not improve from 0.68222
# 2/2 [==============================] - 5s 3s/step - loss: 0.6118 - acc: 0.6433 - val_loss: 0.7162 - val_acc: 0.5461

# %%
from keras.models import load_model

model = load_model('./weights.hdf5')

# %%
transfered.trainable=True
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['acc'])
batch_size=500
epochs=5

# %%
model.fit(dataug(train['file'],train['label'],batch_size=batch_size,randomized=True,random_seed=1),steps_per_epoch=int(np.ceil(len(train)/batch_size)), epochs=epochs,
          validation_data=dataug(test['file'],test['label'],batch_size=batch_size,randomized=True),validation_steps=int(np.ceil(len(test)/batch_size)),
          callbacks=[ModelCheckpoint(filepath='./weights.hdf5',monitor='val_loss',verbose=1,save_best_only=True)],
          verbose=1)
model.load_weights('weights.hdf5')
# Out:
# Epoch 1/5
# 2/2 [==============================] - ETA: 0s - loss: 0.7514 - acc: 0.5250
# Epoch 1: val_loss improved from inf to 0.69814, saving model to ./weights.hdf5
# 2/2 [==============================] - 5s 4s/step - loss: 0.7514 - acc: 0.5250 - val_loss: 0.6981 - val_acc: 0.5390
# Epoch 2/5
# 2/2 [==============================] - ETA: 0s - loss: 0.7389 - acc: 0.5250
# Epoch 2: val_loss did not improve from 0.69814
# 2/2 [==============================] - 6s 3s/step - loss: 0.7389 - acc: 0.5250 - val_loss: 0.7225 - val_acc: 0.4894
# Epoch 3/5
# 2/2 [==============================] - ETA: 0s - loss: 0.7324 - acc: 0.5550
# Epoch 3: val_loss did not improve from 0.69814
# 2/2 [==============================] - 6s 3s/step - loss: 0.7324 - acc: 0.5550 - val_loss: 0.7159 - val_acc: 0.5461
# Epoch 4/5
# 2/2 [==============================] - ETA: 0s - loss: 0.7282 - acc: 0.5250
# Epoch 4: val_loss did not improve from 0.69814
# 2/2 [==============================] - 6s 3s/step - loss: 0.7282 - acc: 0.5250 - val_loss: 0.7005 - val_acc: 0.5390
# Epoch 5/5
# 2/2 [==============================] - ETA: 0s - loss: 0.7036 - acc: 0.5450
# Epoch 5: val_loss improved from 0.69814 to 0.68996, saving model to ./weights.hdf5
# 2/2 [==============================] - 7s 4s/step - loss: 0.7036 - acc: 0.5450 - val_loss: 0.6900 - val_acc: 0.6028

# %%
model.save('model_final.h5')
